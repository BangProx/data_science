# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import random
    
plt.plot([1,2,3,4])
plt.ylabel('y label')
plt.xlabel('x label')
plt.show()

# %%
x = np.linspace(0, np.pi * 2, 100)
plt.title('Sin cos curve')
plt.plot(x, np.sin(x), 'r-', label='sin curve') 
plt.plot(x, np.cos(x), 'b:', label='cos curve') 
plt.xlabel('x value')
plt.ylabel('y value')
plt.legend()#loc = 'upper right' 옵션으로 범례 위치를 이동시킬 수 있다.

# %%
fig, ax = plt.subplots(2,2)

X = np.random.randn(100)
Y = np.random.randn(100)
ax[0,0].scatter(X,Y)
X = np.arange(10)
Y = np.random.uniform(1,10,10)#균일 분포값 생성
ax[0,1].bar(X,Y)
X = np.linspace(0,10,100)
Y = np.cos(X)
ax[1,0].plot(X,Y)
Z = np.random.uniform(0,1,(5,5))
ax[1,1].imshow(Z)

# %%
X = np.arange(10)
Y = np.random.uniform(1,10,10)#균일 분포값 생성.
plt.subplot(grid[0,1:]).bar(X,Y)

X = np.linspace(0,10,100)
Y = np.cos(X)
plt.subplot(grid[1,:2]).plot(X,Y)

Z = np.random.uniform(0,1,(5,5))
plt.subplot(grid[1,2]).imshow(Z)#분포를 2D이미지로 그림.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 X = np.arange(10)
#       2 Y = np.random.uniform(1,10,10)#균일 분포값 생성.
# ----> 3 plt.subplot(grid[0,1:]).bar(X,Y)
#       5 X = np.linspace(0,10,100)
#       6 Y = np.cos(X)
#
# NameError: name 'grid' is not defined

# %%
fig, ax = plt.subplots(2, 3)

grid = plt.GridSpec(2, 3, wspace=0.4, hspace=0.3)
X = np.random.randn(100) # 정규 분포를 가지는 데이터
Y = np.random.randn(100) # 정규 분포를 가지는 데이터 
plt.subplot(grid[0, 0]).scatter(X, Y) # 산점도 그림

X = np.arange(10)                        # 0에서 9 사이의 연속값
Y = np.random.uniform(1, 10, 10)         # 균일분포값 생성
plt.subplot(grid[0, 1:]).bar(X, Y)       # 막대 차트 그림

X = np.linspace(0, 10, 100)
Y = np.cos(X)
plt.subplot(grid[1, :2]).plot(X, Y)      # 실선으로 함수를 그림

Z = np.random.uniform(0, 1, (5, 5))
plt.subplot(grid[1, 2]).imshow(Z)        # 분포를 2D 이미지로 그림
# Out:
# /var/folders/30/hjdnf_613gvb0cd01b74b6x40000gn/T/ipykernel_4533/2183692807.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[0, 0]).scatter(X, Y) # 산점도 그림
# /var/folders/30/hjdnf_613gvb0cd01b74b6x40000gn/T/ipykernel_4533/2183692807.py:10: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[0, 1:]).bar(X, Y)       # 막대 차트 그림
# /var/folders/30/hjdnf_613gvb0cd01b74b6x40000gn/T/ipykernel_4533/2183692807.py:14: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[1, :2]).plot(X, Y)      # 실선으로 함수를 그림
# /var/folders/30/hjdnf_613gvb0cd01b74b6x40000gn/T/ipykernel_4533/2183692807.py:17: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[1, 2]).imshow(Z)        # 분포를 2D 이미지로 그림

# %%
N = 30
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2

plt.scatter(x,y, S=area,c=colors,alpha=0.5)
#s keyword는 점이 찍히는 영역이고, c는 점의 색이다. alpha는 투명도를 의미한다.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 7
#       4 colors = np.random.rand(N)
#       5 area = (30 * np.random.rand(N))**2
# ----> 7 plt.scatter(x,y, S=area,c=colors,alpha=0.5)
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:2862, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2857 @_copy_docstring_and_deprecators(Axes.scatter)
#    2858 def scatter(
#    2859         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2864         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2865         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
#    2866         **({"data": data} if data is not None else {}), **kwargs)
#    2867     sci(__ret)
#    2868     return __ret
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4698, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4694         keys_str = ", ".join(f"'{k}'" for k in extra_keys)
#    4695         _api.warn_external(
#    4696             "No data for colormapping provided via 'c'. "
#    4697             f"Parameters {keys_str} will be ignored")
# -> 4698 collection._internal_update(kwargs)
#    4700 # Classic mode only:
#    4701 # ensure there are margins to allow for the
#    4702 # finite size of the symbols.  In v2.x, margins
#    4703 # are present by default, so we disable this
#    4704 # scatter-specific override.
#    4705 if mpl.rcParams['_internal.classic_mode']:
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
# -> 1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/artist.py:1197, in Artist._update_props(self, props, errfmt)
#    1195             func = getattr(self, f"set_{k}", None)
#    1196             if not callable(func):
# -> 1197                 raise AttributeError(
#    1198                     errfmt.format(cls=type(self), prop_name=k))
#    1199             ret.append(func(v))
#    1200 if ret:
#
# AttributeError: PathCollection.set() got an unexpected keyword argument 'S'

# %%
x = np.arange(3)
years = ['2010','2011','2012']
domestic = [6801,7695,8010]
foreign = [777,1046,1681]

plt.bar(x, domestic,width = 0.25)
plt.bar(x+0.3, foreign,width=0.25)
plt.xticks(x, years)
# Out:
# ([<matplotlib.axis.XTick at 0x13b9b6a10>,
#   <matplotlib.axis.XTick at 0x13b9b69e0>,
#   <matplotlib.axis.XTick at 0x13b9b68f0>],
#  [Text(0, 0, '2010'), Text(1, 0, '2011'), Text(2, 0, '2012')])

# %%
data = [5,4,6,11]
clist = ['cyan','gray','orange','red']
plt.pie(data, autopct='%.2f',colors = clist)
# Out:
# ([<matplotlib.patches.Wedge at 0x13baab790>,
#   <matplotlib.patches.Wedge at 0x13ba2bfd0>,
#   <matplotlib.patches.Wedge at 0x13baab640>,
#   <matplotlib.patches.Wedge at 0x13baab580>],
#  [Text(0.9052822457324836, 0.6248712311841147, ''),
#   Text(-0.13259039153561533, 1.0919797562557798, ''),
#   Text(-1.0680360152839914, 0.2632471653338249, ''),
#   Text(0.26324731532894474, -1.0680359783135132, '')],
#  [Text(0.4937903158540819, 0.3408388533731534, '19.23'),
#   Text(-0.07232203174669927, 0.5956253215940617, '15.38'),
#   Text(-0.5825650992458133, 0.14358936290935903, '23.08'),
#   Text(0.14358944472487895, -0.582565079080098, '42.31')])

# %%
import pandas as pd
df = pd.DataFrame({'색상': clist,
                  '개수': data},index_col = 0)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 import pandas as pd
# ----> 2 df = pd.DataFrame({'색상': clist,
#       3                   '개수': data},col_index = 0)
#       4 df
#
# TypeError: DataFrame.__init__() got an unexpected keyword argument 'col_index'
