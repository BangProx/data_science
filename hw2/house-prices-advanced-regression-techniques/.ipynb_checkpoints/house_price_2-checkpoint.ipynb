# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

train = pd.read_csv('train.csv')
train.head()
test = pd.read_csv('test.csv')
data = pd.concat([train.drop('SalePrice',axis = 1),test],keys = ['train','test'])

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
train.isnull().sum()[train.isnull().sum()>0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
data.isnull().sum()[data.isnull().sum()>0]
# Out:
# MSZoning           4
# LotFrontage      486
# Alley           2721
# Utilities          2
# Exterior1st        1
# Exterior2nd        1
# MasVnrType        24
# MasVnrArea        23
# BsmtQual          81
# BsmtCond          82
# BsmtExposure      82
# BsmtFinType1      79
# BsmtFinSF1         1
# BsmtFinType2      80
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# Electrical         1
# BsmtFullBath       2
# BsmtHalfBath       2
# KitchenQual        1
# Functional         2
# FireplaceQu     1420
# GarageType       157
# GarageYrBlt      159
# GarageFinish     159
# GarageCars         1
# GarageArea         1
# GarageQual       159
# GarageCond       159
# PoolQC          2909
# Fence           2348
# MiscFeature     2814
# SaleType           1
# dtype: int64

# %%
train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
train['Electrical'].unique()
# Out:
# array(['SBrkr', 'FuseF', 'FuseA', 'FuseP', 'Mix', nan], dtype=object)

# %%
train['SalePrice'][train['Electrical'] == 'FuseA'].min()
# Out:
# 34900

# %%
train['MSZoning'].unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
#MSZoning이 RL인 곳의 주택 가격
print(train['SalePrice'][train['MSZoning'] =='RL'].mean())
print(train['SalePrice'][train['MSZoning'] =='RM'].mean())
print(train['SalePrice'][train['MSZoning'] =='FV'].mean())
print(train['SalePrice'][train['MSZoning'] =='RH'].mean())
# Out:
# 191004.99478714162
# 126316.83027522935
# 214014.06153846154
# 131558.375

# %%
train['SalePrice'][train['MSZoning'] =='C']
# Out:
# Series([], Name: SalePrice, dtype: int64)

# %%
print(train['SalePrice'][train['MSZoning'] =='RL'].max())
print(train['SalePrice'][train['MSZoning'] =='RM'].max())
print(train['SalePrice'][train['MSZoning'] =='FV'].max())
print(train['SalePrice'][train['MSZoning'] =='RH'].max())
# Out:
# 755000
# 475000
# 370878
# 200000

# %%
print(train['SalePrice'][train['MSZoning'] =='RL'].min())
print(train['SalePrice'][train['MSZoning'] =='RM'].min())
print(train['SalePrice'][train['MSZoning'] =='FV'].min())
print(train['SalePrice'][train['MSZoning'] =='RH'].min())
# Out:
# 39300
# 37900
# 144152
# 76000

# %%
data = pd.concat([train['SalePrice'],train['GrLivArea']],axis = 1)
data.plot.scatter(x = 'GrLivArea', y = 'SalePrice')
# Out:
# <Axes: xlabel='GrLivArea', ylabel='SalePrice'>

# %%
data = pd.concat([train['SalePrice'],train['TotalBsmtSF']],axis = 1)
data.plot.scatter(x = 'TotalBsmtSF', y = 'SalePrice')
# Out:
# <Axes: xlabel='TotalBsmtSF', ylabel='SalePrice'>

# %%
data = pd.concat([train['SalePrice'],train['OverallQual']],axis = 1)
data.plot.scatter(x = 'OverallQual', y = 'SalePrice')
# Out:
# <Axes: xlabel='OverallQual', ylabel='SalePrice'>

# %%
data = pd.concat([train['SalePrice'],train['YearBuilt']],axis = 1)
data.plot.scatter(x = 'YearBuilt', y = 'SalePrice')
# Out:
# <Axes: xlabel='YearBuilt', ylabel='SalePrice'>

# %%
data = pd.concat([train['SalePrice'],train['Neighborhood']],axis = 1)
data.plot.scatter(x = 'Neighborhood', y = 'SalePrice')
# Out:
# <Axes: xlabel='Neighborhood', ylabel='SalePrice'>

# %%
data = pd.concat([train['SalePrice'],train['Fireplaces']],axis = 1)
data.plot.scatter(x = 'Fireplaces', y = 'SalePrice')
# Out:
# <Axes: xlabel='Fireplaces', ylabel='SalePrice'>

# %%
data = pd.concat([train['SalePrice'],train['OverallQual']],axis = 1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x = 'OverallQual', y = 'SalePrice', data = data)

# %%
data = pd.concat([train['SalePrice'],train['MSZoning']],axis = 1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x = 'MSZoning', y = 'SalePrice', data = data)

# %%
data = pd.concat([train['SalePrice'],train['Neighborhood']],axis = 1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x = 'Neighborhood', y = 'SalePrice', data = data)

# %%
data = pd.concat([train['SalePrice'],train['Electrical']],axis = 1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x = 'Electrical', y = 'SalePrice', data = data)

# %%
#correlation matrix
corr = train.corr()
f, ax = plt.subplots(figsize = (12,9))
sns.heatmap(corr, square = True);
# Out:
# /var/folders/30/hjdnf_613gvb0cd01b74b6x40000gn/T/ipykernel_10284/982727085.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = train.corr()

# %%
#변수가 너무 많아서 확인하기 곤란합니다. 따라서, 변수의 개수를 10개로 제한했습니다.
corr_ten = corr.nlargest(10,'SalePrice')['SalePrice']
corr_ten_idx = corr_ten.index
corr_mat = np.corrcoef(train[corr_ten_idx].values.T)
heatmap = sns.heatmap(corr_mat, cbar=True, annot=True, square=True, fmt='.2f'
                      ,yticklabels = corr_ten_idx.values,xticklabels = corr_ten_idx.values )
plt.show()

# %%
#0.7이상인 애들 강한 상관관계

# %%
corr_df = pd.DataFrame([corr_ten_idx,corr_ten]).T
print(corr_df)
# Out:
#               0         1
# 0     SalePrice       1.0
# 1   OverallQual  0.790982
# 2     GrLivArea  0.708624
# 3    GarageCars  0.640409
# 4    GarageArea  0.623431
# 5   TotalBsmtSF  0.613581
# 6      1stFlrSF  0.605852
# 7      FullBath  0.560664
# 8  TotRmsAbvGrd  0.533723
# 9     YearBuilt  0.522897
